# %% [markdown]
# # Conexion BBDD

# %% [markdown]
# Driver para acceso a BBDD __sqlalchemy__

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (1.4.7)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from sqlalchemy) (1.0.0)

# %%
# !pip install PyMySql
# Out:
# Requirement already satisfied: PyMySql in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (1.0.2)

# %% [markdown]
# Instalar __plugin__ para SQL

# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: six in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: sqlparse in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.4.2)
# Requirement already satisfied: ipython>=1.0 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython-sql) (7.22.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: prettytable<1 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.4.7)
# Requirement already satisfied: appnope in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: pygments in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.8.1)
# Requirement already satisfied: decorator in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.0.6)
# Requirement already satisfied: setuptools>=18.5 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (52.0.0.post20210125)
# Requirement already satisfied: backcall in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.17.2)
# Requirement already satisfied: pexpect>4.3 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.17)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/gabrielsoria/anaconda3/lib/python3.8/site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.0.0)

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# applaunchservices                  0.2.1
# appnope                            0.1.2
# appscript                          1.1.2
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.9.3
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# bokeh                              2.3.2
# boto                               2.49.0
# boto3                              1.20.14
# botocore                           1.23.14
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# certifi                            2020.12.5
# cffi                               1.14.5
# chardet                            4.0.0
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# conda                              4.10.3
# conda-build                        3.21.4
# conda-content-trust                0+unknown
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.4.7
# cycler                             0.10.0
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# decorator                          5.0.6
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.4.0
# docutils                           0.17
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              1.1.2
# fsspec                             0.9.0
# future                             0.18.2
# gevent                             21.1.2
# glob2                              0.7
# gmpy2                              2.0.8
# greenlet                           1.0.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipython-sql                        0.4.0
# ipywidgets                         7.6.3
# isort                              5.8.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# jmespath                           0.10.0
# joblib                             1.0.1
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# keyring                            22.3.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.3.4
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mock                               4.0.3
# more-itertools                     8.7.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.20.1
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.7
# packaging                          20.9
# pandas                             1.2.4
# pandocfilters                      1.4.3
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.2.0
# pip                                21.0.1
# pkginfo                            1.7.0
# pluggy                             0.13.1
# ply                                3.11
# prettytable                        0.7.2
# prometheus-client                  0.10.1
# prompt-toolkit                     3.0.17
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# py4j                               0.10.9.2
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         6.0.0
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# Pygments                           2.8.1
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyMySQL                            1.0.2
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pyspark                            3.2.0
# pytest                             6.2.3
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# pytz                               2021.1
# PyWavelets                         1.1.1
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# regex                              2021.4.4
# requests                           2.25.1
# rope                               0.18.0
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# s3fs                               0.4.2
# s3transfer                         0.5.0
# scikit-image                       0.18.1
# scikit-learn                       0.24.1
# scipy                              1.6.2
# seaborn                            0.11.1
# Send2Trash                         1.5.0
# setuptools                         52.0.0.post20210125
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# six                                1.15.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2.1
# Sphinx                             4.0.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# sqlparse                           0.4.2
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.4.4
# textdistance                       4.2.1
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2020.10.1
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.0.5
# typed-ast                          1.4.2
# typing-extensions                  3.7.4.3
# ujson                              4.0.2
# unicodecsv                         0.14.1
# urllib3                            1.26.4
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# wrapt                              1.12.1
# wurlitzer                          2.1.0
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Cargamos la extensión:

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Conexión a __MySQL__ BBDD __local__

# %% [markdown]
# Sintaxis conexión:
# %sql mysql+pymysql://user:pass@server/database
# Ejemplo servidor remoto:
# %sql mysql+pymysql://ur3fz287jlfaxbko:PFV2KWMAT0FRVO8rFxsq@bxfxbvopjfx0wnm4jjnz-mysql.services.clever-cloud.com/bxfxbvopjfx0wnm4jjnz

# %%
# %sql mysql+pymysql://uvzyojikw6equtfk:uezxmiVEOs0niwYCUEC4@b4xagkgex6krc881bjyk-mysql.services.clever-cloud.com/b4xagkgex6krc881bjyk

# %%
from sqlalchemy import create_engine

# create sqlalchemy engine
conn = create_engine("mysql+pymysql://uvzyojikw6equtfk:uezxmiVEOs0niwYCUEC4@b4xagkgex6krc881bjyk-mysql.services.clever-cloud.com/b4xagkgex6krc881bjyk")

# %%
conn
# Out:
# Engine(mysql+pymysql://uvzyojikw6equtfk:***@b4xagkgex6krc881bjyk-mysql.services.clever-cloud.com/b4xagkgex6krc881bjyk)

# %%
# %sql show tables
# Out:
#  * mysql+pymysql://uvzyojikw6equtfk:***@b4xagkgex6krc881bjyk-mysql.services.clever-cloud.com/b4xagkgex6krc881bjyk
# 6 rows affected.
# [('CO_RUTAS_EQUIPAMIENTOS',),
#  ('DM_AEROLINEAS',),
#  ('DM_AEROPUERTOS',),
#  ('DM_EQUIPAMIENTOS',),
#  ('DM_PAIS',),
#  ('HC_RUTAS',)]

# %% [markdown]
# Comprobamos los datos de la tabla DM_PAIS

# %%
# %sql select * from DM_PAIS
# Out:
#  * mysql+pymysql://uvzyojikw6equtfk:***@b4xagkgex6krc881bjyk-mysql.services.clever-cloud.com/b4xagkgex6krc881bjyk
# 244 rows affected.
# [('ABW', 'Aruba', 'AW', 'NA', 'North America', Decimal('-69.968338'), Decimal('12.521110')),
#  ('AFG', 'Afghanistan', 'AF', 'AS', 'Asia', Decimal('67.709953'), Decimal('33.939110')),
#  ('AGO', 'Angola', 'AO', 'AF', 'Africa', Decimal('17.873887'), Decimal('-11.202692')),
#  ('AIA', 'Anguilla', 'AI', 'NA', 'North America', Decimal('-63.068615'), Decimal('18.220554')),
#  ('ALB', 'Albania', 'AL', 'EU', 'Europe', Decimal('20.168331'), Decimal('41.153332')),
#  ('AND', 'Andorra', 'AD', 'EU', 'Europe', Decimal('1.601554'), Decimal('42.546245')),
#  ('ANT', 'Netherlands Antilles', 'AN', 'EU', 'Europe', Decimal('-69.060087'), Decimal('12.226079')),
#  ('ARE', 'United Arab Emirates', 'AE', 'AS', 'Asia', Decimal('53.847818'), Decimal('23.424076')),
#  ('ARG', 'Argentina', 'AR', 'SA', 'South America', Decimal('-63.616672'), Decimal('-38.416097')),
#  ('ARM', 'Armenia', 'AM', 'AS', 'Asia', Decimal('45.038189'), Decimal('40.069099')),
#  ('ASM', 'American Samoa', 'AS', 'OC', 'Oceania', Decimal('-170.132217'), Decimal('-14.270972')),
#  ('ATA', 'Antarctica', 'AQ', 'AN', 'Antartida', Decimal('-0.071389'), Decimal('-75.250973')),
#  ('ATF', 'French Southern Territories', 'TF', 'AN', 'Antartida', Decimal('69.348557'), Decimal('-49.280366')),
#  ('ATG', 'Antigua and Barbuda', 'AG', 'NA', 'North America', Decimal('-61.796428'), Decimal('17.060816')),
#  ('AUS', 'Australia', 'AU', 'OC', 'Oceania', Decimal('133.775136'), Decimal('-25.274398')),
#  ('AUT', 'Austria', 'AT', 'EU', 'Europe', Decimal('14.550072'), Decimal('47.516231')),
#  ('AZE', 'Azerbaijan', 'AZ', 'AS', 'Asia', Decimal('47.576927'), Decimal('40.143105')),
#  ('BDI', 'Burundi', 'BI', 'AF', 'Africa', Decimal('29.918886'), Decimal('-3.373056')),
#  ('BEL', 'Belgium', 'BE', 'EU', 'Europe', Decimal('4.469936'), Decimal('50.503887')),
#  ('BEN', 'Benin', 'BJ', 'AF', 'Africa', Decimal('2.315834'), Decimal('9.307690')),
#  ('BFA', 'Burkina Faso', 'BF', 'AF', 'Africa', Decimal('-1.561593'), Decimal('12.238333')),
#  ('BGD', 'Bangladesh', 'BD', 'AS', 'Asia', Decimal('90.356331'), Decimal('23.684994')),
#  ('BGR', 'Bulgaria', 'BG', 'EU', 'Europe', Decimal('25.485830'), Decimal('42.733883')),
#  ('BHR', 'Bahrain', 'BH', 'AS', 'Asia', Decimal('50.637772'), Decimal('25.930414')),
#  ('BHS', 'Bahamas', 'BS', 'NA', 'North America', Decimal('-77.396280'), Decimal('25.034280')),
#  ('BIH', 'Bosnia and Herzegovina', 'BA', 'EU', 'Europe', Decimal('17.679076'), Decimal('43.915886')),
#  ('BLR', 'Belarus', 'BY', 'EU', 'Europe', Decimal('27.953389'), Decimal('53.709807')),
#  ('BLZ', 'Belize', 'BZ', 'NA', 'North America', Decimal('-88.497650'), Decimal('17.189877')),
#  ('BMU', 'Bermuda', 'BM', 'NA', 'North America', Decimal('-64.757370'), Decimal('32.321384')),
#  ('BOL', 'Bolivia', 'BO', 'SA', 'South America', Decimal('-63.588653'), Decimal('-16.290154')),
#  ('BRA', 'Brazil', 'BR', 'SA', 'South America', Decimal('-51.925280'), Decimal('-14.235004')),
#  ('BRB', 'Barbados', 'BB', 'NA', 'North America', Decimal('-59.543198'), Decimal('13.193887')),
#  ('BRN', 'Brunei', 'BN', 'AS', 'Asia', Decimal('114.727669'), Decimal('4.535277')),
#  ('BTN', 'Bhutan', 'BT', 'AS', 'Asia', Decimal('90.433601'), Decimal('27.514162')),
#  ('BVT', 'Bouvet Island', 'BV', 'AN', 'Antartida', Decimal('3.413194'), Decimal('-54.423199')),
#  ('BWA', 'Botswana', 'BW', 'AF', 'Africa', Decimal('24.684866'), Decimal('-22.328474')),
#  ('CAF', 'Central African Republic', 'CF', 'AF', 'Africa', Decimal('20.939444'), Decimal('6.611111')),
#  ('CAN', 'Canada', 'CA', 'NA', 'North America', Decimal('-106.346771'), Decimal('56.130366')),
#  ('CCK', 'Cocos (Keeling) Islands', 'CC', 'AS', 'Asia', Decimal('96.870956'), Decimal('-12.164165')),
#  ('CHE', 'Switzerland', 'CH', 'EU', 'Europe', Decimal('8.227512'), Decimal('46.818188')),
#  ('CHL', 'Chile', 'CL', 'SA', 'South America', Decimal('-71.542969'), Decimal('-35.675147')),
#  ('CHN', 'China', 'CN', 'AS', 'Asia', Decimal('104.195397'), Decimal('35.861660')),
#  ('CIV', "Cote d'Ivoire", 'CI', 'AF', 'Africa', Decimal('-5.547080'), Decimal('7.539989')),
#  ('CMR', 'Cameroon', 'CM', 'AF', 'Africa', Decimal('12.354722'), Decimal('7.369722')),
#  ('COD', 'Congo (Kinshasa)', 'CD', 'AF', 'Africa', Decimal('21.758664'), Decimal('-4.038333')),
#  ('COG', 'Congo (Brazzaville)', 'CG', 'AF', 'Africa', Decimal('15.827659'), Decimal('-0.228021')),
#  ('COK', 'Cook Islands', 'CK', 'OC', 'Oceania', Decimal('-159.777671'), Decimal('-21.236736')),
#  ('COL', 'Colombia', 'CO', 'SA', 'South America', Decimal('-74.297333'), Decimal('4.570868')),
#  ('COM', 'Comoros', 'KM', 'AF', 'Africa', Decimal('43.872219'), Decimal('-11.875001')),
#  ('CPV', 'Cape Verde', 'CV', 'AF', 'Africa', Decimal('-24.013197'), Decimal('16.002082')),
#  ('CRI', 'Costa Rica', 'CR', 'NA', 'North America', Decimal('-83.753428'), Decimal('9.748917')),
#  ('CUB', 'Cuba', 'CU', 'NA', 'North America', Decimal('-77.781167'), Decimal('21.521757')),
#  ('CXR', 'Christmas Island', 'CX', 'AS', 'Asia', Decimal('105.690449'), Decimal('-10.447525')),
#  ('CYM', 'Cayman Islands', 'KY', 'NA', 'North America', Decimal('-80.566956'), Decimal('19.513469')),
#  ('CYP', 'Cyprus', 'CY', 'AS', 'Asia', Decimal('33.429859'), Decimal('35.126413')),
#  ('CZE', 'Czech Republic', 'CZ', 'EU', 'Europe', Decimal('15.472962'), Decimal('49.817492')),
#  ('DEU', 'Germany', 'DE', 'EU', 'Europe', Decimal('10.451526'), Decimal('51.165691')),
#  ('DJI', 'Djibouti', 'DJ', 'AF', 'Africa', Decimal('42.590275'), Decimal('11.825138')),
#  ('DMA', 'Dominica', 'DM', 'NA', 'North America', Decimal('-61.370976'), Decimal('15.414999')),
#  ('DNK', 'Denmark', 'DK', 'EU', 'Europe', Decimal('9.501785'), Decimal('56.263920')),
#  ('DOM', 'Dominican Republic', 'DO', 'NA', 'North America', Decimal('-70.162651'), Decimal('18.735693')),
#  ('DZA', 'Algeria', 'DZ', 'AF', 'Africa', Decimal('1.659626'), Decimal('28.033886')),
#  ('ECU', 'Ecuador', 'EC', 'SA', 'South America', Decimal('-78.183406'), Decimal('-1.831239')),
#  ('EGY', 'Egypt', 'EG', 'AF', 'Africa', Decimal('30.802498'), Decimal('26.820553')),
#  ('ERI', 'Eritrea', 'ER', 'AF', 'Africa', Decimal('39.782334'), Decimal('15.179384')),
#  ('ESH', 'Western Sahara', 'EH', 'AF', 'Africa', Decimal('-12.885834'), Decimal('24.215527')),
#  ('ESP', 'Spain', 'ES', 'EU', 'Europe', Decimal('-3.749220'), Decimal('40.463667')),
#  ('EST', 'Estonia', 'EE', 'EU', 'Europe', Decimal('25.013607'), Decimal('58.595272')),
#  ('ETH', 'Ethiopia', 'ET', 'AF', 'Africa', Decimal('40.489673'), Decimal('9.145000')),
#  ('FIN', 'Finland', 'FI', 'EU', 'Europe', Decimal('25.748151'), Decimal('61.924110')),
#  ('FJI', 'Fiji', 'FJ', 'OC', 'Oceania', Decimal('179.414413'), Decimal('-16.578193')),
#  ('FLK', 'Falkland Islands (Malvinas)', 'FK', 'SA', 'South America', Decimal('-59.523613'), Decimal('-51.796253')),
#  ('FRA', 'France', 'FR', 'EU', 'Europe', Decimal('2.213749'), Decimal('46.227638')),
#  ('FRO', 'Faroe Islands', 'FO', 'EU', 'Europe', Decimal('-6.911806'), Decimal('61.892635')),
#  ('FSM', 'Micronesia', 'FM', 'OC', 'Oceania', Decimal('150.550812'), Decimal('7.425554')),
#  ('GAB', 'Gabon', 'GA', 'AF', 'Africa', Decimal('11.609444'), Decimal('-0.803689')),
#  ('GBR', 'United Kingdom', 'GB', 'EU', 'Europe', Decimal('-3.435973'), Decimal('55.378051')),
#  ('GEO', 'Georgia', 'GE', 'AS', 'Asia', Decimal('43.356892'), Decimal('42.315407')),
#  ('GGY', 'Guernsey', 'GG', 'EU', 'Europe', Decimal('-2.585278'), Decimal('49.465691')),
#  ('GHA', 'Ghana', 'GH', 'AF', 'Africa', Decimal('-1.023194'), Decimal('7.946527')),
#  ('GIB', 'Gibraltar', 'GI', 'EU', 'Europe', Decimal('-5.345374'), Decimal('36.137741')),
#  ('GIN', 'Guinea', 'GN', 'AF', 'Africa', Decimal('-9.696645'), Decimal('9.945587')),
#  ('GLP', 'Guadeloupe', 'GP', 'NA', 'North America', Decimal('-62.067641'), Decimal('16.995971')),
#  ('GMB', 'Gambia', 'GM', 'AF', 'Africa', Decimal('-15.310139'), Decimal('13.443182')),
#  ('GNB', 'Guinea-Bissau', 'GW', 'AF', 'Africa', Decimal('-15.180413'), Decimal('11.803749')),
#  ('GNQ', 'Equatorial Guinea', 'GQ', 'AF', 'Africa', Decimal('10.267895'), Decimal('1.650801')),
#  ('GRC', 'Greece', 'GR', 'EU', 'Europe', Decimal('21.824312'), Decimal('39.074208')),
#  ('GRD', 'Grenada', 'GD', 'NA', 'North America', Decimal('-61.604171'), Decimal('12.262776')),
#  ('GRL', 'Greenland', 'GL', 'NA', 'North America', Decimal('-42.604303'), Decimal('71.706936')),
#  ('GTM', 'Guatemala', 'GT', 'NA', 'North America', Decimal('-90.230759'), Decimal('15.783471')),
#  ('GUF', 'French Guiana', 'GF', 'SA', 'South America', Decimal('-53.125782'), Decimal('3.933889')),
#  ('GUM', 'Guam', 'GU', 'OC', 'Oceania', Decimal('144.793731'), Decimal('13.444304')),
#  ('GUY', 'Guyana', 'GY', 'SA', 'South America', Decimal('-58.930180'), Decimal('4.860416')),
#  ('HKG', 'Hong Kong', 'HK', 'AS', 'Asia', Decimal('114.109497'), Decimal('22.396428')),
#  ('HMD', 'Heard Island and McDonald Mcdonald Islands', 'HM', 'AN', 'Antartida', Decimal('73.504158'), Decimal('-53.081810')),
#  ('HND', 'Honduras', 'HN', 'NA', 'North America', Decimal('-86.241905'), Decimal('15.199999')),
#  ('HRV', 'Croatia', 'HR', 'EU', 'Europe', Decimal('15.200000'), Decimal('45.100000')),
#  ('HTI', 'Haiti', 'HT', 'NA', 'North America', Decimal('-72.285215'), Decimal('18.971187')),
#  ('HUN', 'Hungary', 'HU', 'EU', 'Europe', Decimal('19.503304'), Decimal('47.162494')),
#  ('IDN', 'Indonesia', 'ID', 'AS', 'Asia', Decimal('113.921327'), Decimal('-0.789275')),
#  ('IMN', 'Isle of Man', 'IM', 'EU', 'Europe', Decimal('-4.548056'), Decimal('54.236107')),
#  ('IND', 'India', 'IN', 'AS', 'Asia', Decimal('78.962880'), Decimal('20.593684')),
#  ('IOT', 'British Indian Ocean Territory', 'IO', 'AS', 'Asia', Decimal('71.876519'), Decimal('-6.343194')),
#  ('IRL', 'Ireland', 'IE', 'EU', 'Europe', Decimal('-8.243890'), Decimal('53.412910')),
#  ('IRN', 'Iran', 'IR', 'AS', 'Asia', Decimal('53.688046'), Decimal('32.427908')),
#  ('IRQ', 'Iraq', 'IQ', 'AS', 'Asia', Decimal('43.679291'), Decimal('33.223191')),
#  ('ISL', 'Iceland', 'IS', 'EU', 'Europe', Decimal('-19.020835'), Decimal('64.963051')),
#  ('ISR', 'Israel', 'IL', 'AS', 'Asia', Decimal('34.851612'), Decimal('31.046051')),
#  ('ITA', 'Italy', 'IT', 'EU', 'Europe', Decimal('12.567380'), Decimal('41.871940')),
#  ('JAM', 'Jamaica', 'JM', 'NA', 'North America', Decimal('-77.297508'), Decimal('18.109581')),
#  ('JEY', 'Jersey', 'JE', 'EU', 'Europe', Decimal('-2.131250'), Decimal('49.214439')),
#  ('JOR', 'Jordan', 'JO', 'AS', 'Asia', Decimal('36.238414'), Decimal('30.585164')),
#  ('JPN', 'Japan', 'JP', 'AS', 'Asia', Decimal('138.252924'), Decimal('36.204824')),
#  ('KAZ', 'Kazakhstan', 'KZ', 'AS', 'Asia', Decimal('66.923684'), Decimal('48.019573')),
#  ('KEN', 'Kenya', 'KE', 'AF', 'Africa', Decimal('37.906193'), Decimal('-0.023559')),
#  ('KGZ', 'Kyrgyzstan', 'KG', 'AS', 'Asia', Decimal('74.766098'), Decimal('41.204380')),
#  ('KHM', 'Cambodia', 'KH', 'AS', 'Asia', Decimal('104.990963'), Decimal('12.565679')),
#  ('KIR', 'Kiribati', 'KI', 'OC', 'Oceania', Decimal('-168.734039'), Decimal('-3.370417')),
#  ('KNA', 'Saint Kitts and Nevis', 'KN', 'NA', 'North America', Decimal('-62.782998'), Decimal('17.357822')),
#  ('KOR', 'South Korea', 'KR', 'AS', 'Asia', Decimal('127.766922'), Decimal('35.907757')),
#  ('KWT', 'Kuwait', 'KW', 'AS', 'Asia', Decimal('47.481766'), Decimal('29.311660')),
#  ('LAO', 'Laos', 'LA', 'AS', 'Asia', Decimal('102.495496'), Decimal('19.856270')),
#  ('LBN', 'Lebanon', 'LB', 'AS', 'Asia', Decimal('35.862285'), Decimal('33.854721')),
#  ('LBR', 'Liberia', 'LR', 'AF', 'Africa', Decimal('-9.429499'), Decimal('6.428055')),
#  ('LBY', 'Libya', 'LY', 'AF', 'Africa', Decimal('17.228331'), Decimal('26.335100')),
#  ('LCA', 'Saint Lucia', 'LC', 'NA', 'North America', Decimal('-60.978893'), Decimal('13.909444')),
#  ('LIE', 'Liechtenstein', 'LI', 'EU', 'Europe', Decimal('9.555373'), Decimal('47.166000')),
#  ('LKA', 'Sri Lanka', 'LK', 'AS', 'Asia', Decimal('80.771797'), Decimal('7.873054')),
#  ('LSO', 'Lesotho', 'LS', 'AF', 'Africa', Decimal('28.233608'), Decimal('-29.609988')),
#  ('LTU', 'Lithuania', 'LT', 'EU', 'Europe', Decimal('23.881275'), Decimal('55.169438')),
#  ('LUX', 'Luxembourg', 'LU', 'EU', 'Europe', Decimal('6.129583'), Decimal('49.815273')),
#  ('LVA', 'Latvia', 'LV', 'EU', 'Europe', Decimal('24.603189'), Decimal('56.879635')),
#  ('MAC', 'Macao', 'MO', 'AS', 'Asia', Decimal('113.543873'), Decimal('22.198745')),
#  ('MAR', 'Morocco', 'MA', 'AF', 'Africa', Decimal('-7.092620'), Decimal('31.791702')),
#  ('MCO', 'Monaco', 'MC', 'EU', 'Europe', Decimal('7.412841'), Decimal('43.750298')),
#  ('MDA', 'Moldova', 'MD', 'EU', 'Europe', Decimal('28.369885'), Decimal('47.411631')),
#  ('MDG', 'Madagascar', 'MG', 'AF', 'Africa', Decimal('46.869107'), Decimal('-18.766947')),
#  ('MDV', 'Maldives', 'MV', 'AS', 'Asia', Decimal('73.220680'), Decimal('3.202778')),
#  ('MEX', 'Mexico', 'MX', 'NA', 'North America', Decimal('-102.552784'), Decimal('23.634501')),
#  ('MHL', 'Marshall Islands', 'MH', 'OC', 'Oceania', Decimal('171.184478'), Decimal('7.131474')),
#  ('MKD', 'Macedonia', 'MK', 'EU', 'Europe', Decimal('21.745275'), Decimal('41.608635')),
#  ('MLI', 'Mali', 'ML', 'AF', 'Africa', Decimal('-3.996166'), Decimal('17.570692')),
#  ('MLT', 'Malta', 'MT', 'EU', 'Europe', Decimal('14.375416'), Decimal('35.937496')),
#  ('MMR', 'Myanmar', 'MM', 'AS', 'Asia', Decimal('95.956223'), Decimal('21.913965')),
#  ('MNE', 'Montenegro', 'ME', 'EU', 'Europe', Decimal('19.374390'), Decimal('42.708678')),
#  ('MNG', 'Mongolia', 'MN', 'AS', 'Asia', Decimal('103.846656'), Decimal('46.862496')),
#  ('MNP', 'Northern Mariana Islands', 'MP', 'OC', 'Oceania', Decimal('145.384690'), Decimal('17.330830')),
#  ('MOZ', 'Mozambique', 'MZ', 'AF', 'Africa', Decimal('35.529562'), Decimal('-18.665695')),
#  ('MRT', 'Mauritania', 'MR', 'AF', 'Africa', Decimal('-10.940835'), Decimal('21.007890')),
#  ('MSR', 'Montserrat', 'MS', 'NA', 'North America', Decimal('-62.187366'), Decimal('16.742498')),
#  ('MTQ', 'Martinique', 'MQ', 'NA', 'North America', Decimal('-61.024174'), Decimal('14.641528')),
#  ('MUS', 'Mauritius', 'MU', 'AF', 'Africa', Decimal('57.552152'), Decimal('-20.348404')),
#  ('MWI', 'Malawi', 'MW', 'AF', 'Africa', Decimal('34.301525'), Decimal('-13.254308')),
#  ('MYS', 'Malaysia', 'MY', 'AS', 'Asia', Decimal('101.975766'), Decimal('4.210484')),
#  ('MYT', 'Mayotte', 'YT', 'AF', 'Africa', Decimal('45.166244'), Decimal('-12.827500')),
#  ('NAM', 'Namibia', 'NM', 'AF', 'Africa', Decimal('18.490410'), Decimal('-22.957640')),
#  ('NCL', 'New Caledonia', 'NC', 'OC', 'Oceania', Decimal('165.618042'), Decimal('-20.904305')),
#  ('NER', 'Niger', 'NE', 'AF', 'Africa', Decimal('8.081666'), Decimal('17.607789')),
#  ('NFK', 'Norfolk Island', 'NF', 'OC', 'Oceania', Decimal('167.954712'), Decimal('-29.040835')),
#  ('NGA', 'Nigeria', 'NG', 'AF', 'Africa', Decimal('8.675277'), Decimal('9.081999')),
#  ('NIC', 'Nicaragua', 'NI', 'NA', 'North America', Decimal('-85.207229'), Decimal('12.865416')),
#  ('NIU', 'Niue', 'NU', 'OC', 'Oceania', Decimal('-169.867233'), Decimal('-19.054445')),
#  ('NLD', 'Netherlands', 'NL', 'EU', 'Europe', Decimal('5.291266'), Decimal('52.132633')),
#  ('NOR', 'Norway', 'NO', 'EU', 'Europe', Decimal('8.468946'), Decimal('60.472024')),
#  ('NPL', 'Nepal', 'NP', 'AS', 'Asia', Decimal('84.124008'), Decimal('28.394857')),
#  ('NRU', 'Nauru', 'NR', 'OC', 'Oceania', Decimal('166.931503'), Decimal('-0.522778')),
#  ('NZL', 'New Zealand', 'NZ', 'OC', 'Oceania', Decimal('174.885971'), Decimal('-40.900557')),
#  ('OMN', 'Oman', 'OM', 'AS', 'Asia', Decimal('55.923255'), Decimal('21.512583')),
#  ('PAK', 'Pakistan', 'PK', 'AS', 'Asia', Decimal('69.345116'), Decimal('30.375321')),
#  ('PAN', 'Panama', 'PA', 'NA', 'North America', Decimal('-80.782127'), Decimal('8.537981')),
#  ('PCN', 'Pitcairn', 'PN', 'OC', 'Oceania', Decimal('-127.439308'), Decimal('-24.703615')),
#  ('PER', 'Peru', 'PE', 'SA', 'South America', Decimal('-75.015152'), Decimal('-9.189967')),
#  ('PHL', 'Philippines', 'PH', 'AS', 'Asia', Decimal('121.774017'), Decimal('12.879721')),
#  ('PLW', 'Palau', 'PW', 'OC', 'Oceania', Decimal('134.582520'), Decimal('7.514980')),
#  ('PNG', 'Papua New Guinea', 'PG', 'OC', 'Oceania', Decimal('143.955550'), Decimal('-6.314993')),
#  ('POL', 'Poland', 'PL', 'EU', 'Europe', Decimal('19.145136'), Decimal('51.919438')),
#  ('PRI', 'Puerto Rico', 'PR', 'NA', 'North America', Decimal('-66.590149'), Decimal('18.220833')),
#  ('PRK', 'North Korea', 'KP', 'AS', 'Asia', Decimal('127.510093'), Decimal('40.339852')),
#  ('PRT', 'Portugal', 'PT', 'EU', 'Europe', Decimal('-8.224454'), Decimal('39.399872')),
#  ('PRY', 'Paraguay', 'PY', 'SA', 'South America', Decimal('-58.443832'), Decimal('-23.442503')),
#  ('PSE', 'Palestine', 'PS', 'AS', 'Asia', Decimal('35.233154'), Decimal('31.952162')),
#  ('PYF', 'French Polynesia', 'PF', 'OC', 'Oceania', Decimal('-149.406843'), Decimal('-17.679742')),
#  ('QAT', 'Qatar', 'QA', 'AS', 'Asia', Decimal('51.183884'), Decimal('25.354826')),
#  ('REU', 'Reunion', 'RE', 'AF', 'Africa', Decimal('55.536384'), Decimal('-21.115141')),
#  ('ROU', 'Romania', 'RO', 'EU', 'Europe', Decimal('24.966760'), Decimal('45.943161')),
#  ('RUS', 'Russia', 'RU', 'EU', 'Europe', Decimal('105.318756'), Decimal('61.524010')),
#  ('RWA', 'Rwanda', 'RW', 'AF', 'Africa', Decimal('29.873888'), Decimal('-1.940278')),
#  ('SAU', 'Saudi Arabia', 'SA', 'AS', 'Asia', Decimal('45.079162'), Decimal('23.885942')),
#  ('SDN', 'Sudan', 'SD', 'AF', 'Africa', Decimal('30.217636'), Decimal('12.862807')),
#  ('SEN', 'Senegal', 'SN', 'AF', 'Africa', Decimal('-14.452362'), Decimal('14.497401')),
#  ('SGP', 'Singapore', 'SG', 'AS', 'Asia', Decimal('103.819836'), Decimal('1.352083')),
#  ('SGS', 'South Georgia and the Islands', 'GS', 'AN', 'Antartida', Decimal('-36.587909'), Decimal('-54.429579')),
#  ('SHN', 'Saint Helena', 'SH', 'AF', 'Africa', Decimal('-10.030696'), Decimal('-24.143474')),
#  ('SJM', 'Svalbard', 'SJ', 'EU', 'Europe', Decimal('23.670272'), Decimal('77.553604')),
#  ('SLB', 'Solomon Islands', 'SB', 'OC', 'Oceania', Decimal('160.156194'), Decimal('-9.645710')),
#  ('SLE', 'Sierra Leone', 'SL', 'AF', 'Africa', Decimal('-11.779889'), Decimal('8.460555')),
#  ('SLV', 'El Salvador', 'SV', 'NA', 'North America', Decimal('-88.896530'), Decimal('13.794185')),
#  ('SMR', 'San Marino', 'SM', 'EU', 'Europe', Decimal('12.457777'), Decimal('43.942360')),
#  ('SOM', 'Somalia', 'SO', 'AF', 'Africa', Decimal('46.199616'), Decimal('5.152149')),
#  ('SPM', 'Saint Pierre and Miquelon', 'PM', 'NA', 'North America', Decimal('-56.271110'), Decimal('46.941936')),
#  ('SRB', 'Serbia', 'RS', 'EU', 'Europe', Decimal('21.005859'), Decimal('44.016521')),
#  ('STP', 'Sao Tome and Principe', 'ST', 'AF', 'Africa', Decimal('6.613081'), Decimal('0.186360')),
#  ('SUR', 'Suriname', 'SR', 'SA', 'South America', Decimal('-56.027783'), Decimal('3.919305')),
#  ('SVK', 'Slovakia', 'SK', 'EU', 'Europe', Decimal('19.699024'), Decimal('48.669026')),
#  ('SVN', 'Slovenia', 'SI', 'EU', 'Europe', Decimal('14.995463'), Decimal('46.151241')),
#  ('SWE', 'Sweden', 'SE', 'EU', 'Europe', Decimal('18.643501'), Decimal('60.128161')),
#  ('SWZ', 'Swaziland', 'SZ', 'AF', 'Africa', Decimal('31.465866'), Decimal('-26.522503')),
#  ('SYC', 'Seychelles', 'SC', 'AF', 'Africa', Decimal('55.491977'), Decimal('-4.679574')),
#  ('SYR', 'Syria', 'SY', 'AS', 'Asia', Decimal('38.996815'), Decimal('34.802075')),
#  ('TCA', 'Turks and Caicos Islands', 'TC', 'NA', 'North America', Decimal('-71.797928'), Decimal('21.694025')),
#  ('TCD', 'Chad', 'TD', 'AF', 'Africa', Decimal('18.732207'), Decimal('15.454166')),
#  ('TGO', 'Togo', 'TG', 'AF', 'Africa', Decimal('0.824782'), Decimal('8.619543')),
#  ('THA', 'Thailand', 'TH', 'AS', 'Asia', Decimal('100.992541'), Decimal('15.870032')),
#  ('TJK', 'Tajikistan', 'TJ', 'AS', 'Asia', Decimal('71.276093'), Decimal('38.861034')),
#  ('TKL', 'Tokelau', 'TK', 'OC', 'Oceania', Decimal('-171.855881'), Decimal('-8.967363')),
#  ('TKM', 'Turkmenistan', 'TM', 'AS', 'Asia', Decimal('59.556278'), Decimal('38.969719')),
#  ('TLS', 'East Timor', 'TL', 'AS', 'Asia', Decimal('125.727539'), Decimal('-8.874217')),
#  ('TON', 'Tonga', 'TO', 'OC', 'Oceania', Decimal('-175.198242'), Decimal('-21.178986')),
#  ('TTO', 'Trinidad and Tobago', 'TT', 'NA', 'North America', Decimal('-61.222503'), Decimal('10.691803')),
#  ('TUN', 'Tunisia', 'TN', 'AF', 'Africa', Decimal('9.537499'), Decimal('33.886917')),
#  ('TUR', 'Turkey', 'TR', 'EU', 'Europe', Decimal('35.243322'), Decimal('38.963745')),
#  ('TUV', 'Tuvalu', 'TV', 'OC', 'Oceania', Decimal('177.649330'), Decimal('-7.109535')),
#  ('TWN', 'Taiwan', 'TW', 'AS', 'Asia', Decimal('120.960515'), Decimal('23.697810')),
#  ('TZA', 'Tanzania', 'TZ', 'AF', 'Africa', Decimal('34.888822'), Decimal('-6.369028')),
#  ('UGA', 'Uganda', 'UG', 'AF', 'Africa', Decimal('32.290275'), Decimal('1.373333')),
#  ('UKR', 'Ukraine', 'UA', 'EU', 'Europe', Decimal('31.165580'), Decimal('48.379433')),
#  ('UMI', 'United States Minor Outlying Islands', 'UM', 'OC', 'Oceania', None, None),
#  ('URY', 'Uruguay', 'UY', 'SA', 'South America', Decimal('-55.765835'), Decimal('-32.522779')),
#  ('USA', 'United States', 'US', 'NA', 'North America', Decimal('-95.712891'), Decimal('37.090240')),
#  ('UZB', 'Uzbekistan', 'UZ', 'AS', 'Asia', Decimal('64.585262'), Decimal('41.377491')),
#  ('VAT', 'Holy See (Vatican City State)', 'VA', 'EU', 'Europe', Decimal('12.453389'), Decimal('41.902916')),
#  ('VCT', 'Saint Vincent and the Grenadines', 'VC', 'NA', 'North America', Decimal('-61.287228'), Decimal('12.984305')),
#  ('VEN', 'Venezuela', 'VE', 'SA', 'South America', Decimal('-66.589730'), Decimal('6.423750')),
#  ('VGB', 'British Virgin Islands', 'VG', 'NA', 'North America', Decimal('-64.639968'), Decimal('18.420695')),
#  ('VIR', 'US Virgin Islands', 'VI', 'NA', 'North America', Decimal('-64.896335'), Decimal('18.335765')),
#  ('VNM', 'Vietnam', 'VN', 'AS', 'Asia', Decimal('108.277199'), Decimal('14.058324')),
#  ('VUT', 'Vanuatu', 'VU', 'OC', 'Oceania', Decimal('166.959158'), Decimal('-15.376706')),
#  ('WLF', 'Wallis and Futuna', 'WF', 'OC', 'Oceania', Decimal('-177.156097'), Decimal('-13.768752')),
#  ('WSM', 'Samoa', 'WS', 'OC', 'Oceania', Decimal('-172.104629'), Decimal('-13.759029')),
#  ('YEM', 'Yemen', 'YE', 'AS', 'Asia', Decimal('48.516388'), Decimal('15.552727')),
#  ('Z99', 'desconocido', 'Z9', 'Z9', 'desconocido', None, None),
#  ('ZAF', 'South Africa', 'ZA', 'AF', 'Africa', Decimal('22.937506'), Decimal('-30.559482')),
#  ('ZMB', 'Zambia', 'ZM', 'AF', 'Africa', Decimal('27.849332'), Decimal('-13.133897')),
#  ('ZWE', 'Zimbabwe', 'ZW', 'AF', 'Africa', Decimal('29.154857'), Decimal('-19.015438'))]

# %% [markdown]
# Cuestiones de __configuración__

# %%
 # %config SqlMagic
# Out:
# SqlMagic(Magics, Configurable) options
# ------------------------------------
# SqlMagic.autocommit=<Bool>
#     Set autocommit mode
#     Current: True
# SqlMagic.autolimit=<Int>
#     Automatically limit the size of the returned result sets
#     Current: 0
# SqlMagic.autopandas=<Bool>
#     Return Pandas DataFrames instead of regular result sets
#     Current: False
# SqlMagic.column_local_vars=<Bool>
#     Return data into local variables from column names
#     Current: False
# SqlMagic.displaycon=<Bool>
#     Show connection string after execute
#     Current: True
# SqlMagic.displaylimit=<Int>
#     Automatically limit the number of rows displayed (full result set is still
#     stored)
#     Current: None
# SqlMagic.dsn_filename=<Unicode>
#     Path to DSN file. When the first argument is of the form [section], a
#     sqlalchemy connection string is formed from the matching section in the DSN
#     file.
#     Current: 'odbc.ini'
# SqlMagic.feedback=<Bool>
#     Print number of rows affected by DML
#     Current: True
# SqlMagic.short_errors=<Bool>
#     Don't display the full traceback on SQL Programming Error
#     Current: True
# SqlMagic.style=<Unicode>
#     Set the table printing style to any of prettytable's defined styles
#     (currently DEFAULT, MSWORD_FRIENDLY, PLAIN_COLUMNS, RANDOM)
#     Current: 'DEFAULT'

# %%
# %config SqlMagic.autolimit = 20
