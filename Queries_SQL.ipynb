# %%
# %run ETL.ipynb

# %% [markdown]
# ## SQL Queries

# %% [markdown]
# ### 1. Número de rutas por pais

# %%
query1 = """
    select t2.pais_aeropuerto, count(t1.cod_aeropuerto_ori) as num_rutas from
    (
        select cod_aeropuerto_ori
        from HC_RUTAS

    ) t1 join 
    (
        select cod_aeropuerto, pais_aeropuerto from DM_AEROPUERTOS AS t2
    ) t2 on cod_aeropuerto_ori=cod_aeropuerto
    group by pais_aeropuerto
    order by num_rutas desc, cod_aeropuerto_ori
    """

# %%
# %sql $query1
# Out:
#  * mysql+pymysql://uvzyojikw6equtfk:***@b4xagkgex6krc881bjyk-mysql.services.clever-cloud.com/b4xagkgex6krc881bjyk
# (pymysql.err.OperationalError) (2013, 'Lost connection to MySQL server during query')
# [SQL: select t2.pais_aeropuerto, count(t1.cod_aeropuerto_ori) as num_rutas from ( select cod_aeropuerto_ori from HC_RUTAS ) t1 join ( select cod_aeropuerto, pais_aeropuerto from DM_AEROPUERTOS AS t2 ) t2 on cod_aeropuerto_ori=cod_aeropuerto group by pais_aeropuerto order by num_rutas desc, cod_aeropuerto_ori]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### 2. Número de rutas de cada país, como país de la aerolínea ordenadas de forma que salga el primero el país con más rutas. Mostrar el nombre del país.

# %%
query2 = """
    select t2.pais_aerolinea, count(t1.cod_aerolinea) as num_rutas from
    (
        select cod_aerolinea from HC_RUTAS
    ) as t1 join 
    (
        select cod_aerolinea, nombre_aerolinea, pais_aerolinea from DM_AEROLINEAS AS t2
    ) as t2 on t2.COD_AEROLINEA=t1.cod_aerolinea
    group by pais_aerolinea 
    order by num_rutas desc, pais_aerolinea
"""

# %%
# %sql $query2
# Out:
#  * mysql+pymysql://uvzyojikw6equtfk:***@b4xagkgex6krc881bjyk-mysql.services.clever-cloud.com/b4xagkgex6krc881bjyk
# 167 rows affected.
# [('United States', 12785),
#  ('China', 7262),
#  ('United Kingdom', 3336),
#  ('Germany', 2942),
#  ('Ireland', 2760),
#  ('France', 2044),
#  ('Russia', 1830),
#  ('Canada', 1662),
#  ('India', 1441),
#  ('Japan', 1373),
#  ('Italy', 1300),
#  ('Netherlands', 1151),
#  ('Turkey', 1142),
#  ('Australia', 1092),
#  ('Spain', 1064),
#  ('Brazil', 1052),
#  ('United Arab Emirates', 977),
#  ('Taiwan', 880),
#  ('Mexico', 808),
#  ('Norway', 786),
#  ('Indonesia', 768),
#  (None, 679),
#  ('Malaysia', 642),
#  ('Sweden', 634),
#  ('Republic of Korea', 615),
#  ('ALASKA', 530),
#  ('Saudi Arabia', 493),
#  ('Hungary', 463),
#  ('Singapore', 447),
#  ('Philippines', 430),
#  ('Thailand', 428),
#  ('Austria', 425),
#  ('Portugal', 417),
#  ('Iran', 416),
#  ('Greece', 392),
#  ('Switzerland', 388),
#  ('Chile', 338),
#  ('Ethiopia', 337),
# ...

# %% [markdown]
# ### 3. Número de rutas de cada equipamiento ordenadas de forma que salga el primero el equipamiento con más rutas. Mostrar el nombre del equipamiento. Mostrar solo los equipamientos con más de 2000 rutas.

# %%
query3="""
select t2.desc_equipamiento, t1.num_rutas from 
(
    select cod_equipamiento, count(cod_equipamiento) as num_rutas 
    from CO_RUTAS_EQUIPAMIENTOS
    group by cod_equipamiento
) t1 join
(
    select cod_equipamiento, desc_equipamiento from DM_EQUIPAMIENTOS
) t2 on t2.cod_equipamiento=t1.cod_equipamiento
where num_rutas > 2000
order by num_rutas desc, desc_equipamiento
"""

# %%
# %sql $query3
# Out:
#  * mysql+pymysql://uvzyojikw6equtfk:***@b4xagkgex6krc881bjyk-mysql.services.clever-cloud.com/b4xagkgex6krc881bjyk
# 8 rows affected.
# [('Airbus A320-100/200                           ', 15184),
#  ('Boeing 737-800 pax                            ', 10183),
#  ('Airbus A319                                   ', 7535),
#  ('Airbus A321-100/200                           ', 3512),
#  ('Boeing 737-800 (winglets) pax                 ', 3223),
#  ('Boeing 737 all pax models                     ', 2759),
#  ('Boeing 737-700 (winglets) pax                 ', 2446),
#  ('Canadair Regional Jet                         ', 2180)]

# %% [markdown]
# ### 4. Número de rutas por equipamiento para las rutas cuyo aeropuerto origen es Barajas (1229) ordenadas de forma que salga el primero el equipamiento con más rutas. Mostrar el nombre del equipamiento.

# %%
query4 = """
select t3.desc_equipamiento, count(t2.cod_ruta) as num_rutas from
(
    select cod_ruta, cod_equipamiento
    from CO_RUTAS_EQUIPAMIENTOS
) t1 inner join
(
    select cod_ruta, cod_aeropuerto_ori from HC_RUTAS where cod_aeropuerto_ori = 1229
) t2 on t1.cod_ruta=t2.cod_ruta join
(
    select cod_equipamiento, desc_equipamiento from DM_EQUIPAMIENTOS
) t3 on t1.cod_equipamiento=t3.cod_equipamiento
group by desc_equipamiento
order by num_rutas desc
"""

# %%
# %sql $query4
# Out:
#  * mysql+pymysql://uvzyojikw6equtfk:***@b4xagkgex6krc881bjyk-mysql.services.clever-cloud.com/b4xagkgex6krc881bjyk
# 45 rows affected.
# [('Boeing 737-800 pax                            ', 62),
#  ('Airbus A320-100/200                           ', 61),
#  ('Airbus A319                                   ', 55),
#  ('Airbus A321-100/200                           ', 29),
#  ('Airbus A330-300                               ', 27),
#  ('Airbus A318/319/320/321                       ', 20),
#  ('Airbus A340-600                               ', 20),
#  ('Embraer 190                                   ', 19),
#  ('Airbus A330-200                               ', 18),
#  ('Canadair Regional Jet 1000                    ', 18),
#  ('Canadair Regional Jet 900                     ', 14),
#  ('Airbus A330 all models                        ', 13),
#  ('Canadair Regional Jet 200                     ', 11),
#  ('Airbus A340-500                               ', 10),
# ...

# %% [markdown]
# ### 5.  Los dos países entre los que hay más rutas.

# %%
query5 = """
SELECT t2.pais_aeropuerto AS Origen, t3.pais_aeropuerto AS Destino, COUNT(*) AS num_rutas FROM
(
    SELECT cod_aeropuerto_ori,cod_aeropuerto_des FROM HC_RUTAS
) t1 
JOIN 
(
    SELECT cod_aeropuerto, pais_aeropuerto FROM DM_AEROPUERTOS
) t2 ON t1.cod_aeropuerto_ori=t2.cod_aeropuerto
JOIN
(
   SELECT cod_aeropuerto, pais_aeropuerto FROM DM_AEROPUERTOS
) t3 ON t1.cod_aeropuerto_des=t3.cod_aeropuerto 
WHERE t2.pais_aeropuerto != t3.pais_aeropuerto
GROUP BY Origen,Destino
ORDER BY num_rutas desc
LIMIT 1
"""

# %%
# %sql $query5
# Out:
#  * mysql+pymysql://uvzyojikw6equtfk:***@b4xagkgex6krc881bjyk-mysql.services.clever-cloud.com/b4xagkgex6krc881bjyk
# 1 rows affected.
# [('United Kingdom', 'Spain', 518)]
